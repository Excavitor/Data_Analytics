# %% [markdown]
# # Shad Abdullah, Intern ID - i23b0034s05

# %% [markdown]
# # Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

tc = sns.load_dataset("titanic")

# %matplotlib inline

# %%
fact_table = pd.read_excel(r'e-com-sales-out.xlsx', sheet_name='Fact_table', engine='openpyxl')
item_dim = pd.read_excel(r'e-com-sales-out.xlsx', sheet_name='Item_dim', engine='openpyxl')
customer_dim = pd.read_excel(r'e-com-sales-out.xlsx', sheet_name='Customer_dim', engine='openpyxl')
time_dim = pd.read_excel(r'e-com-sales-out.xlsx', sheet_name='Time_dim', engine='openpyxl')
store_dim = pd.read_excel(r'e-com-sales-out.xlsx', sheet_name='Store_dim', engine='openpyxl')

# %%
fact_table
# Out:
#      payment_key coustomer_key time_key item_key store_key  quantity  unit  \
# 0           P025       C001495   T08774   I00185     S0038        19    ct
# 1           P009       C000904   T09092   I00017     S0007         8  cans
# 2           P019       C001627   T03980   I00235     S0013         1    ct
# 3           P004       C001606   T00982   I00232     S0038         7    ct
# 4           P019       C001273   T09057   I00075     S0012        35  cans
# ...          ...           ...      ...      ...       ...       ...   ...
# 9995        P007       C001501   T06807   I00028     S0007        10  cans
# 9996        P004       C000405   T02560   I00143     S0031        43    ct
# 9997        P015       C001789   T07589   I00142     S0021       152    ct
# 9998        P003       C001500   T00881   I00194     S0037        19  bars
# 9999        P013       C000035   T02979   I00120     S0041         1    ct
#
#       unit_price  total_price
# 0          14.00        266.0
# 1           6.75         54.0
# 2          14.00         14.0
# 3          12.00         84.0
# 4          15.50        542.5
# ...          ...          ...
# 9995        6.75         67.5
# 9996       16.00        688.0
# 9997       12.50       1900.0
# 9998       23.00        437.0
# 9999        9.00          9.0
#
# [10000 rows x 9 columns]

# %% [markdown]
# # Practice problem 6.1
# Show the unit price frequency of the fact table using Displot.

# %%
sns.set_style('darkgrid')
sns.displot(x=fact_table['unit_price'], bins = 20)
plt.title('unit price frequency of the fact table')
plt.xlabel('Unit Price');
# Out:
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Practice problem 6.2
# Show the quantity vs total price into a Join plot where the kind must be scatter.

# %%
sns.jointplot(x=fact_table['quantity'],y=fact_table['total_price'],kind = 'scatter');
plt.title('quantity vs total price')
plt.legend(['Quantity','Total Price'])
plt.xlabel('Quantity')
plt.ylabel('Total Price');
# Out:
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Practice problem 6.3
# Show the item_dim into a pair plot.

# %%
sns.pairplot(item_dim)
# Out:
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# # Practice problem 6.4
# Find the Quarter-wise average sales price and plot it into a pie chart.

# %%
df = pd.merge(fact_table,time_dim, on = 'time_key')
df
# Out:
#      payment_key coustomer_key time_key item_key store_key  quantity  unit  \
# 0           P025       C001495   T08774   I00185     S0038        19    ct
# 1           P021       C000822   T08774   I00197     S0031         5  bars
# 2           P009       C000904   T09092   I00017     S0007         8  cans
# 3           P019       C001627   T03980   I00235     S0013         1    ct
# 4           P004       C001606   T00982   I00232     S0038         7    ct
# ...          ...           ...      ...      ...       ...       ...   ...
# 9995        P011       C001627   T09655   I00201     S0018        13  bars
# 9996        P028       C000693   T01596   I00061     S0040         4  cans
# 9997        P031       C001098   T03137   I00054     S0006        22  cans
# 9998        P014       C001214   T04049   I00251     S0035        62    oz
# 9999        P007       C001501   T06807   I00028     S0007        10  cans
#
#       unit_price  total_price              date  hour  day      week  month  \
# 0          14.00        266.0  08-06-2021 23:18    23    8  2nd Week      6
# 1          15.00         75.0  08-06-2021 23:18    23    8  2nd Week      6
# 2           6.75         54.0  03-12-2019 02:40     2    3  1st Week     12
# 3          14.00         14.0  12-10-2014 15:27    15   12  2nd Week     10
# 4          12.00         84.0  18-10-2019 17:11    17   18  3rd Week     10
# ...          ...          ...               ...   ...  ...       ...    ...
# 9995       23.00        299.0  23-04-2019 16:36    16   23  4th Week      4
# 9996       55.00        220.0  05-11-2018 09:57     9    5  1st Week     11
# 9997       40.00        880.0  12-04-2014 20:34    20   12  2nd Week      4
# 9998       13.00        806.0  08-03-2020 19:47    19    8  2nd Week      3
# 9999        6.75         67.5  23-02-2015 17:40    17   23  4th Week      2
#
#      quarter  year
# 0         Q2  2021
# 1         Q2  2021
# 2         Q4  2019
# 3         Q4  2014
# 4         Q4  2019
# ...      ...   ...
# 9995      Q2  2019
# 9996      Q4  2018
# 9997      Q2  2014
# 9998      Q1  2020
# 9999      Q1  2015
#
# [10000 rows x 16 columns]

# %%
df1 = df.groupby(['quarter'])['total_price'].mean().reset_index()
df1
# Out:
#   quarter  total_price
# 0      Q1  1313.095640
# 1      Q2  1065.591894
# 2      Q3  1103.236231
# 3      Q4  1103.905627

# %%
plt.pie(labels=['Q1','Q2','Q3','Q4'],x=df1.total_price);

# %% [markdown]
# # Practice problem 6.5
# Show the unit count from the fact table into a count plot

# %%
a= fact_table['unit'].value_counts()
plt.figure(figsize = (15,5))
sns.countplot(data=fact_table, x='unit', order=a.index);
# Out:
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# # Practice problem 6.6

# %% [markdown]
# It was Not given in the question. So, i left it empty.

# %% [markdown]
# # Practice problem 6.7
# Compare the total sales price in year-wise quarterly between Dhaka and Chittagong, and plot it into a Scatter Chart.

# %%
add_customer_time_with_fact = pd.merge(pd.merge(fact_table, time_dim, on='time_key'), customer_dim, on='coustomer_key')
add_customer_time_with_fact
# Out:
#      payment_key coustomer_key time_key item_key store_key  quantity  unit  \
# 0           P025       C001495   T08774   I00185     S0038        19    ct
# 1           P015       C001495   T08338   I00008     S0015        24  cans
# 2           P025       C001495   T02924   I00034     S0005        19  cans
# 3           P027       C001495   T01362   I00031     S0026        11  cans
# 4           P020       C001495   T00256   I00201     S0024         5  bars
# ...          ...           ...      ...      ...       ...       ...   ...
# 9995        P031       C000379   T08995   I00145     S0043       319    ct
# 9996        P038       C000379   T08880   I00010     S0021         1  cans
# 9997        P036       C000666   T03804   I00150     S0011        16  bags
# 9998        P009       C000521   T05526   I00098     S0009        54    oz
# 9999        P029       C001095   T09404   I00101     S0011       109  tubs
#
#       unit_price  total_price              date  ...  quarter  year  \
# 0          14.00       266.00  08-06-2021 23:18  ...       Q2  2021
# 1          16.25       390.00  18-02-2021 21:55  ...       Q1  2021
# 2          16.00       304.00  23-10-2016 22:45  ...       Q4  2016
# 3          16.00       176.00  25-04-2022 05:46  ...       Q2  2022
# 4          23.00       115.00  22-05-2020 14:55  ...       Q2  2020
# ...          ...          ...               ...  ...      ...   ...
# 9995       17.00      5423.00  30-06-2018 01:56  ...       Q2  2018
# 9996        6.75         6.75  31-10-2015 10:27  ...       Q4  2015
# 9997       16.00       256.00  24-12-2018 22:12  ...       Q4  2018
# 9998       10.00       540.00  18-03-2017 20:42  ...       Q1  2017
# 9999       15.00      1635.00  26-10-2021 20:45  ...       Q4  2021
#
#                        name     contact_no            nid  \
# 0     ankita kanwar rathore  8801997470114  7043709914237
# 1     ankita kanwar rathore  8801997470114  7043709914237
# 2     ankita kanwar rathore  8801997470114  7043709914237
# 3     ankita kanwar rathore  8801997470114  7043709914237
# 4     ankita kanwar rathore  8801997470114  7043709914237
# ...                     ...            ...            ...
# 9995               jitender  8801651547315  2102034287287
# 9996               jitender  8801651547315  2102034287287
# 9997                  divya  8801982495444  8375355196536
# 9998         abhinav vashit  8801510794174  2370175929783
# 9999                  varsa  8801717054409  7759088504576
#
#                                                 address  \
# 0     220 West Dhanmondi, Rd-19 (Old), 10/A (New), D...
# 1     220 West Dhanmondi, Rd-19 (Old), 10/A (New), D...
# 2     220 West Dhanmondi, Rd-19 (Old), 10/A (New), D...
# 3     220 West Dhanmondi, Rd-19 (Old), 10/A (New), D...
# 4     220 West Dhanmondi, Rd-19 (Old), 10/A (New), D...
# ...                                                 ...
# 9995           514, Iqbal Road, Mohammadpur, Dhaka-1207
# 9996           514, Iqbal Road, Mohammadpur, Dhaka-1207
# 9997  Rurual Development Officer, BRDB Gournadi, Bar...
# 9998                House-08, Road-10/A, Sec-09, Uttara
# 9999                       Lakhan khola, Megna, Comilla
#
#                                            street      upazila  district  \
# 0     220 West Dhanmondi, Rd-19 (Old), 10/A (New)    Dhanmondi     Dhaka
# 1     220 West Dhanmondi, Rd-19 (Old), 10/A (New)    Dhanmondi     Dhaka
# 2     220 West Dhanmondi, Rd-19 (Old), 10/A (New)    Dhanmondi     Dhaka
# 3     220 West Dhanmondi, Rd-19 (Old), 10/A (New)    Dhanmondi     Dhaka
# 4     220 West Dhanmondi, Rd-19 (Old), 10/A (New)    Dhanmondi     Dhaka
# ...                                           ...          ...       ...
# 9995                              514, Iqbal Road  Mohammadpur     Dhaka
# 9996                              514, Iqbal Road  Mohammadpur     Dhaka
# 9997    Rurual Development Officer, BRDB Gournadi     Gournadi  Barishal
# 9998                  House-08, Road-10/A, Sec-09       Uttara     Dhaka
# 9999                                 Lakhan khola        Megna   Comilla
#
#         division
# 0          Dhaka
# 1          Dhaka
# 2          Dhaka
# 3          Dhaka
# 4          Dhaka
# ...          ...
# 9995       Dhaka
# 9996       Dhaka
# 9997    Barishal
# 9998       Dhaka
# 9999  Chittagong
#
# [10000 rows x 24 columns]

# %%
quarter_wise_div = add_customer_time_with_fact[(add_customer_time_with_fact['division'] == 'Dhaka') | (add_customer_time_with_fact['division'] == 'Chittagong')]
quarter_wise_div
# Out:
#      payment_key coustomer_key time_key item_key store_key  quantity     unit  \
# 0           P025       C001495   T08774   I00185     S0038        19       ct
# 1           P015       C001495   T08338   I00008     S0015        24     cans
# 2           P025       C001495   T02924   I00034     S0005        19     cans
# 3           P027       C001495   T01362   I00031     S0026        11     cans
# 4           P020       C001495   T00256   I00201     S0024         5     bars
# ...          ...           ...      ...      ...       ...       ...      ...
# 9994        P002       C000275   T05566   I00087     S0018         4  bottles
# 9995        P031       C000379   T08995   I00145     S0043       319       ct
# 9996        P038       C000379   T08880   I00010     S0021         1     cans
# 9998        P009       C000521   T05526   I00098     S0009        54       oz
# 9999        P029       C001095   T09404   I00101     S0011       109     tubs
#
#       unit_price  total_price              date  ...  quarter  year  \
# 0          14.00       266.00  08-06-2021 23:18  ...       Q2  2021
# 1          16.25       390.00  18-02-2021 21:55  ...       Q1  2021
# 2          16.00       304.00  23-10-2016 22:45  ...       Q4  2016
# 3          16.00       176.00  25-04-2022 05:46  ...       Q2  2022
# 4          23.00       115.00  22-05-2020 14:55  ...       Q2  2020
# ...          ...          ...               ...  ...      ...   ...
# 9994       15.00        60.00  13-01-2022 16:13  ...       Q1  2022
# 9995       17.00      5423.00  30-06-2018 01:56  ...       Q2  2018
# 9996        6.75         6.75  31-10-2015 10:27  ...       Q4  2015
# 9998       10.00       540.00  18-03-2017 20:42  ...       Q1  2017
# 9999       15.00      1635.00  26-10-2021 20:45  ...       Q4  2021
#
#                        name     contact_no            nid  \
# 0     ankita kanwar rathore  8801997470114  7043709914237
# 1     ankita kanwar rathore  8801997470114  7043709914237
# 2     ankita kanwar rathore  8801997470114  7043709914237
# 3     ankita kanwar rathore  8801997470114  7043709914237
# 4     ankita kanwar rathore  8801997470114  7043709914237
# ...                     ...            ...            ...
# 9994                  rajan  8801840304624  7690981033461
# 9995               jitender  8801651547315  2102034287287
# 9996               jitender  8801651547315  2102034287287
# 9998         abhinav vashit  8801510794174  2370175929783
# 9999                  varsa  8801717054409  7759088504576
#
#                                                 address  \
# 0     220 West Dhanmondi, Rd-19 (Old), 10/A (New), D...
# 1     220 West Dhanmondi, Rd-19 (Old), 10/A (New), D...
# 2     220 West Dhanmondi, Rd-19 (Old), 10/A (New), D...
# 3     220 West Dhanmondi, Rd-19 (Old), 10/A (New), D...
# 4     220 West Dhanmondi, Rd-19 (Old), 10/A (New), D...
# ...                                                 ...
# 9994  Block-E, Road-06 4th Floor Bashundhara R/A, Dhaka
# 9995           514, Iqbal Road, Mohammadpur, Dhaka-1207
# 9996           514, Iqbal Road, Mohammadpur, Dhaka-1207
# 9998                House-08, Road-10/A, Sec-09, Uttara
# 9999                       Lakhan khola, Megna, Comilla
#
#                                            street          upazila  district  \
# 0     220 West Dhanmondi, Rd-19 (Old), 10/A (New)        Dhanmondi     Dhaka
# 1     220 West Dhanmondi, Rd-19 (Old), 10/A (New)        Dhanmondi     Dhaka
# 2     220 West Dhanmondi, Rd-19 (Old), 10/A (New)        Dhanmondi     Dhaka
# 3     220 West Dhanmondi, Rd-19 (Old), 10/A (New)        Dhanmondi     Dhaka
# 4     220 West Dhanmondi, Rd-19 (Old), 10/A (New)        Dhanmondi     Dhaka
# ...                                           ...              ...       ...
# 9994   Block-E, Road-06 4th Floor Bashundhara R/A  Bashundhara R/A     Dhaka
# 9995                              514, Iqbal Road      Mohammadpur     Dhaka
# 9996                              514, Iqbal Road      Mohammadpur     Dhaka
# 9998                  House-08, Road-10/A, Sec-09           Uttara     Dhaka
# 9999                                 Lakhan khola            Megna   Comilla
#
#         division
# 0          Dhaka
# 1          Dhaka
# 2          Dhaka
# 3          Dhaka
# 4          Dhaka
# ...          ...
# 9994       Dhaka
# 9995       Dhaka
# 9996       Dhaka
# 9998       Dhaka
# 9999  Chittagong
#
# [8869 rows x 24 columns]

# %%
total_sales_per_quarter = quarter_wise_div.groupby(['year', 'quarter', 'division'])['total_price'].sum().reset_index()
total_sales_per_quarter
# Out:
#     year quarter    division  total_price
# 0   2014      Q1  Chittagong     62294.50
# 1   2014      Q1       Dhaka    101744.50
# 2   2014      Q2  Chittagong    105954.50
# 3   2014      Q2       Dhaka    140499.25
# 4   2014      Q3  Chittagong     22175.25
# ..   ...     ...         ...          ...
# 67  2022      Q2       Dhaka    178415.75
# 68  2022      Q3  Chittagong     13322.75
# 69  2022      Q3       Dhaka    328979.75
# 70  2022      Q4  Chittagong     27536.00
# 71  2022      Q4       Dhaka    106376.00
#
# [72 rows x 4 columns]

# %%
plt.figure(figsize=(12, 8))
sns.set_style('darkgrid')
sns.scatterplot(data=total_sales_per_quarter, x='quarter', y='total_price', hue='division')
plt.title('Total Sales Price per Quarter')
plt.xlabel('Quarter')
plt.ylabel('Total Sales Price')
plt.show()
# Out:
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# # Practice problem 6.8
# Break down the total sales of items geographically (division-wise).
#
# 1. Plot division-wise total sales price into SwarmChart.
# 2. Plot item-wise total sales price into SwarmChart.

# %% [markdown]
# # 1

# %%
df_div = pd.merge(fact_table, customer_dim, on = 'coustomer_key')
df_div
# Out:
#      payment_key coustomer_key time_key item_key store_key  quantity  unit  \
# 0           P025       C001495   T08774   I00185     S0038        19    ct
# 1           P015       C001495   T08338   I00008     S0015        24  cans
# 2           P027       C001495   T01362   I00031     S0026        11  cans
# 3           P025       C001495   T02924   I00034     S0005        19  cans
# 4           P020       C001495   T00256   I00201     S0024         5  bars
# ...          ...           ...      ...      ...       ...       ...   ...
# 9995        P009       C000521   T05526   I00098     S0009        54    oz
# 9996        P036       C001300   T05352   I00194     S0014         1  bars
# 9997        P017       C001030   T03591   I00231     S0017        37    pk
# 9998        P029       C001095   T09404   I00101     S0011       109  tubs
# 9999        P038       C001780   T03208   I00123     S0009        15    ct
#
#       unit_price  total_price                   name     contact_no  \
# 0          14.00        266.0  ankita kanwar rathore  8801997470114
# 1          16.25        390.0  ankita kanwar rathore  8801997470114
# 2          16.00        176.0  ankita kanwar rathore  8801997470114
# 3          16.00        304.0  ankita kanwar rathore  8801997470114
# 4          23.00        115.0  ankita kanwar rathore  8801997470114
# ...          ...          ...                    ...            ...
# 9995       10.00        540.0         abhinav vashit  8801510794174
# 9996       23.00         23.0            shathi davi  8801675679969
# 9997       16.00        592.0           munbura bibi  8801568692764
# 9998       15.00       1635.0                  varsa  8801717054409
# 9999       45.00        675.0       preeti chaudhary  8801547960725
#
#                 nid                                            address  \
# 0     7043709914237  220 West Dhanmondi, Rd-19 (Old), 10/A (New), D...
# 1     7043709914237  220 West Dhanmondi, Rd-19 (Old), 10/A (New), D...
# 2     7043709914237  220 West Dhanmondi, Rd-19 (Old), 10/A (New), D...
# 3     7043709914237  220 West Dhanmondi, Rd-19 (Old), 10/A (New), D...
# 4     7043709914237  220 West Dhanmondi, Rd-19 (Old), 10/A (New), D...
# ...             ...                                                ...
# 9995  2370175929783                House-08, Road-10/A, Sec-09, Uttara
# 9996  5354188190768                                   South Keranigong
# 9997  6729866815723  Block-E, Road-06 4th Floor Bashundhara R/A, Dhaka
# 9998  7759088504576                       Lakhan khola, Megna, Comilla
# 9999  3819017239476    Janata Housing, Agargaon, Shere-E-Bangla Nagar.
#
#                                            street          upazila district  \
# 0     220 West Dhanmondi, Rd-19 (Old), 10/A (New)        Dhanmondi    Dhaka
# 1     220 West Dhanmondi, Rd-19 (Old), 10/A (New)        Dhanmondi    Dhaka
# 2     220 West Dhanmondi, Rd-19 (Old), 10/A (New)        Dhanmondi    Dhaka
# 3     220 West Dhanmondi, Rd-19 (Old), 10/A (New)        Dhanmondi    Dhaka
# 4     220 West Dhanmondi, Rd-19 (Old), 10/A (New)        Dhanmondi    Dhaka
# ...                                           ...              ...      ...
# 9995                  House-08, Road-10/A, Sec-09           Uttara    Dhaka
# 9996                             South Keranigong       Keranigong    Dhaka
# 9997   Block-E, Road-06 4th Floor Bashundhara R/A  Bashundhara R/A    Dhaka
# 9998                                 Lakhan khola            Megna  Comilla
# 9999                               Janata Housing         Agargaon    Dhaka
#
#         division
# 0          Dhaka
# 1          Dhaka
# 2          Dhaka
# 3          Dhaka
# 4          Dhaka
# ...          ...
# 9995       Dhaka
# 9996       Dhaka
# 9997       Dhaka
# 9998  Chittagong
# 9999       Dhaka
#
# [10000 rows x 17 columns]

# %% [markdown]
# sns.swarmplot(y = df_div['total_price'], x = df_div['division'])

# %% [markdown]
# # 2

# %% [markdown]
# df_item = pd.merge(fact_table, item_dim, on = 'item_key')
# df_item

# %% [markdown]
# sns.swarmplot(y = df_item['age'], x = df_item['pclass'])

# %% [markdown]
# # Practice problem 6.9
# Break down year-wise the total sales geographically (division-wise) and plot it into Stripplot.

# %%
add_customer_time_with_fact_6_9 = pd.merge(pd.merge(fact_table, time_dim, on='time_key'), customer_dim, on='coustomer_key')
add_customer_time_with_fact_6_9
# Out:
#      payment_key coustomer_key time_key item_key store_key  quantity  unit  \
# 0           P025       C001495   T08774   I00185     S0038        19    ct
# 1           P015       C001495   T08338   I00008     S0015        24  cans
# 2           P025       C001495   T02924   I00034     S0005        19  cans
# 3           P027       C001495   T01362   I00031     S0026        11  cans
# 4           P020       C001495   T00256   I00201     S0024         5  bars
# ...          ...           ...      ...      ...       ...       ...   ...
# 9995        P031       C000379   T08995   I00145     S0043       319    ct
# 9996        P038       C000379   T08880   I00010     S0021         1  cans
# 9997        P036       C000666   T03804   I00150     S0011        16  bags
# 9998        P009       C000521   T05526   I00098     S0009        54    oz
# 9999        P029       C001095   T09404   I00101     S0011       109  tubs
#
#       unit_price  total_price              date  ...  quarter  year  \
# 0          14.00       266.00  08-06-2021 23:18  ...       Q2  2021
# 1          16.25       390.00  18-02-2021 21:55  ...       Q1  2021
# 2          16.00       304.00  23-10-2016 22:45  ...       Q4  2016
# 3          16.00       176.00  25-04-2022 05:46  ...       Q2  2022
# 4          23.00       115.00  22-05-2020 14:55  ...       Q2  2020
# ...          ...          ...               ...  ...      ...   ...
# 9995       17.00      5423.00  30-06-2018 01:56  ...       Q2  2018
# 9996        6.75         6.75  31-10-2015 10:27  ...       Q4  2015
# 9997       16.00       256.00  24-12-2018 22:12  ...       Q4  2018
# 9998       10.00       540.00  18-03-2017 20:42  ...       Q1  2017
# 9999       15.00      1635.00  26-10-2021 20:45  ...       Q4  2021
#
#                        name     contact_no            nid  \
# 0     ankita kanwar rathore  8801997470114  7043709914237
# 1     ankita kanwar rathore  8801997470114  7043709914237
# 2     ankita kanwar rathore  8801997470114  7043709914237
# 3     ankita kanwar rathore  8801997470114  7043709914237
# 4     ankita kanwar rathore  8801997470114  7043709914237
# ...                     ...            ...            ...
# 9995               jitender  8801651547315  2102034287287
# 9996               jitender  8801651547315  2102034287287
# 9997                  divya  8801982495444  8375355196536
# 9998         abhinav vashit  8801510794174  2370175929783
# 9999                  varsa  8801717054409  7759088504576
#
#                                                 address  \
# 0     220 West Dhanmondi, Rd-19 (Old), 10/A (New), D...
# 1     220 West Dhanmondi, Rd-19 (Old), 10/A (New), D...
# 2     220 West Dhanmondi, Rd-19 (Old), 10/A (New), D...
# 3     220 West Dhanmondi, Rd-19 (Old), 10/A (New), D...
# 4     220 West Dhanmondi, Rd-19 (Old), 10/A (New), D...
# ...                                                 ...
# 9995           514, Iqbal Road, Mohammadpur, Dhaka-1207
# 9996           514, Iqbal Road, Mohammadpur, Dhaka-1207
# 9997  Rurual Development Officer, BRDB Gournadi, Bar...
# 9998                House-08, Road-10/A, Sec-09, Uttara
# 9999                       Lakhan khola, Megna, Comilla
#
#                                            street      upazila  district  \
# 0     220 West Dhanmondi, Rd-19 (Old), 10/A (New)    Dhanmondi     Dhaka
# 1     220 West Dhanmondi, Rd-19 (Old), 10/A (New)    Dhanmondi     Dhaka
# 2     220 West Dhanmondi, Rd-19 (Old), 10/A (New)    Dhanmondi     Dhaka
# 3     220 West Dhanmondi, Rd-19 (Old), 10/A (New)    Dhanmondi     Dhaka
# 4     220 West Dhanmondi, Rd-19 (Old), 10/A (New)    Dhanmondi     Dhaka
# ...                                           ...          ...       ...
# 9995                              514, Iqbal Road  Mohammadpur     Dhaka
# 9996                              514, Iqbal Road  Mohammadpur     Dhaka
# 9997    Rurual Development Officer, BRDB Gournadi     Gournadi  Barishal
# 9998                  House-08, Road-10/A, Sec-09       Uttara     Dhaka
# 9999                                 Lakhan khola        Megna   Comilla
#
#         division
# 0          Dhaka
# 1          Dhaka
# 2          Dhaka
# 3          Dhaka
# 4          Dhaka
# ...          ...
# 9995       Dhaka
# 9996       Dhaka
# 9997    Barishal
# 9998       Dhaka
# 9999  Chittagong
#
# [10000 rows x 24 columns]

# %%
total_sales_per_year = add_customer_time_with_fact_6_9.groupby(['year', 'division'])['total_price'].sum().reset_index()
total_sales_per_year
# Out:
#     year    division  total_price
# 0   2014    Barishal     32051.00
# 1   2014  Chittagong    219465.00
# 2   2014       Dhaka    650813.75
# 3   2014      Sylhet     58053.50
# 4   2015    Barishal     73342.75
# 5   2015  Chittagong    194361.50
# 6   2015       Dhaka    864945.25
# 7   2015      Sylhet    103111.00
# 8   2016    Barishal     18916.50
# 9   2016  Chittagong    152138.75
# 10  2016       Dhaka   1141480.25
# 11  2016      Sylhet     88295.75
# 12  2017    Barishal     74187.50
# 13  2017  Chittagong    116989.75
# 14  2017       Dhaka    874240.00
# 15  2017      Sylhet    130886.25
# 16  2018    Barishal     29735.00
# 17  2018  Chittagong    172473.75
# 18  2018       Dhaka    859647.50
# 19  2018      Sylhet    121235.50
# 20  2019    Barishal     61427.75
# 21  2019  Chittagong    238622.00
# 22  2019       Dhaka   1079075.25
# 23  2019      Sylhet    136160.50
# 24  2020    Barishal     99741.50
# 25  2020  Chittagong    200972.25
# 26  2020       Dhaka   1201869.50
# 27  2020      Sylhet     82990.25
# 28  2021    Barishal     38184.75
# 29  2021  Chittagong    164669.25
# 30  2021       Dhaka    969313.50
# 31  2021      Sylhet     92920.25
# 32  2022    Barishal     54638.00
# 33  2022  Chittagong    157183.25
# 34  2022       Dhaka    843750.00
# 35  2022      Sylhet     52444.50

# %%
plt.figure(figsize=(12, 8))
sns.set_style('darkgrid')
sns.stripplot(data=total_sales_per_year, x='year', y='total_price', hue='division')
plt.title('Year and Division')
plt.xlabel('Year')
plt.ylabel('Total Sales Price')
plt.legend(title='Division')
plt.show();
# Out:
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Practice problem 6.10
# What was the distribution of Ages for passengers in different classes?

# %%
grid = sns.FacetGrid(tc, row='pclass', hue='sex', height=3)
grid.map(sns.kdeplot, 'age', shade=True)
grid.add_legend()

 
sns.despine(left=True, bottom=True)

plt.show()
# Out:
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Saad\OneDrive - northsouth.edu\Internship\shadVenv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
